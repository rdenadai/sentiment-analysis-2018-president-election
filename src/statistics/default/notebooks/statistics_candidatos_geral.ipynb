# %%
import sys
sys.path.append('..')
sys.path.append('../..')

from stats import *

from peewee import SQL
from database.models import RawFacebookComments, RawTwitterComments, RawInstagramComments, RawYouTubeComments, RawHashtagComments

# %% [markdown]
# ## Estatísticas perfis dos Candidatos

# %% [markdown]
# ### Comentários no Facebook dos Candidatos
#
# Apresentando estatísticas de todos os comentários coletados do Facebook.

# %% [markdown]
# #### Primeiro turno

# %%
query = RawFacebookComments.select() \
        .where(
            (SQL('length(clean_comment) > 0')) & 
            (RawFacebookComments.timestamp <= datetime.date(2018, 10, 7))
        ) \
        .order_by(RawFacebookComments.data)

# %%
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')

create_wordcloud(query)
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 53999
# Média palavras por Comentário: 6.7
# Qtde de Usuários             : 33820

# %%
graph_most_words_freq_by_date(RawFacebookComments, query, turno=1, most_common=10)

# %% [markdown]
# #### Segundo Turno

# %%
query = RawFacebookComments.select() \
        .where(
            (SQL('length(clean_comment) > 0')) & 
            (RawFacebookComments.timestamp > datetime.date(2018, 10, 7))
        ) \
        .order_by(RawFacebookComments.data)

# %%
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')

create_wordcloud(query)
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 13026
# Média palavras por Comentário: 8.36
# Qtde de Usuários             : 11075

# %%
graph_most_words_freq_by_date(RawFacebookComments, query, turno=2, most_common=10)

# %% [markdown]
# #### Primeiro + Segundo Turno

# %%
query = RawFacebookComments.select() \
        .where(SQL('length(clean_comment) > 0')) \
        .order_by(RawFacebookComments.hash)

# %%
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')

create_wordcloud(query)
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 67025
# Média palavras por Comentário: 7.02
# Qtde de Usuários             : 42921

# %%
graph_most_words_freq_by_date(RawFacebookComments, query, most_common=10)

# %% [markdown]
# ### Comentários no Twitter dos Candidatos

# %% [markdown]
# #### Primeiro Turno

# %%
query = RawTwitterComments.select() \
        .where(
            (SQL('length(clean_comment) > 0')) & 
            (RawTwitterComments.timestamp <= datetime.date(2018, 10, 7))
        ) \
        .order_by(RawTwitterComments.data)

# %%
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')

create_wordcloud(query)
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 91000
# Média palavras por Comentário: 6.71
# Qtde de Usuários             : 37150

# %%
graph_most_words_freq_by_date(RawTwitterComments, query, turno=1, most_common=10)

# %% [markdown]
# #### Segundo Turno

# %%
query = RawTwitterComments.select() \
        .where(
            (SQL('length(clean_comment) > 0')) & 
            (RawTwitterComments.timestamp > datetime.date(2018, 10, 7))
        ) \
        .order_by(RawTwitterComments.data)

# %%
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')

create_wordcloud(query)
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 29082
# Média palavras por Comentário: 7.08
# Qtde de Usuários             : 15426

# %%
graph_most_words_freq_by_date(RawTwitterComments, query, turno=2, most_common=10)

# %% [markdown]
# #### Primeiro + Segundo Turno

# %%
query = RawTwitterComments.select() \
        .where(SQL('length(clean_comment) > 0')) \
        .order_by(RawTwitterComments.hash)

# %%
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')

create_wordcloud(query)
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 120082
# Média palavras por Comentário: 6.8
# Qtde de Usuários             : 48582

# %%
graph_most_words_freq_by_date(RawTwitterComments, query, most_common=10)

# %% [markdown]
# ### Comentários no Instagram dos Candidatos

# %%
query = RawInstagramComments.select() \
        .where(SQL('length(clean_comment) > 0')) \
        .order_by(RawInstagramComments.hash)

# %%
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')

create_wordcloud(query)
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 38739
# Média palavras por Comentário: 6.03
# Qtde de Usuários             : 23472

# %% [markdown]
# ### Comentários no YouTube dos Candidatos

# %%
query = RawYouTubeComments.select() \
        .where(SQL('length(clean_comment) > 0')) \
        .order_by(RawYouTubeComments.hash)

# %%
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')

create_wordcloud(query)
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 8487
# Média palavras por Comentário: 7.45
# Qtde de Usuários             : 4992

# %% [markdown]
# ## Estatísticas Twitter (hashtags)
#
# Estatísicas gerais do twitter, baseadas em todas as hashtags coletadas durante as eleições, indiferente de candidatos.

# %% [markdown]
# ### Primeiro turno

# %%
query = RawHashtagComments.select() \
        .where(
            (SQL('length(clean_comment) > 0')) & 
            (RawHashtagComments.timestamp <= datetime.date(2018, 10, 7))
        ) \
        .order_by(RawHashtagComments.data)

# %%
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')

create_wordcloud(query)
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 71439
# Média palavras por Comentário: 8.61
# Qtde de Usuários             : 37752

# %%
graph_most_words_freq_by_date(RawHashtagComments, query, turno=1, most_common=10)

# %% [markdown]
# ### Segundo turno

# %%
query = RawHashtagComments.select() \
        .where(
            (SQL('length(clean_comment) > 0')) & 
            (RawHashtagComments.timestamp > datetime.date(2018, 10, 7))
        ) \
        .order_by(RawHashtagComments.data)

# %%
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')

create_wordcloud(query)
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 211235
# Média palavras por Comentário: 7.78
# Qtde de Usuários             : 105741

# %%
graph_most_words_freq_by_date(RawHashtagComments, query, turno=2, most_common=10)

# %% [markdown]
# ### Primeiro + Segundo turno

# %%
query = RawHashtagComments.select() \
        .where(SQL('length(clean_comment) > 0')) \
        .order_by(RawHashtagComments.data)

# %%
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')

create_wordcloud(query)
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 282674
# Média palavras por Comentário: 7.99
# Qtde de Usuários             : 131946

# %%
graph_most_words_freq_by_date(RawHashtagComments, query, most_common=10)
