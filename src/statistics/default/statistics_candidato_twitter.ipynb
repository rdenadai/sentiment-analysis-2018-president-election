# %%
import sys
sys.path.append('..')
sys.path.append('../..')

from stats import *

from peewee import SQL
from database.models import RawTwitterComments

# %% [markdown]
# ## Jair Bolsonaro

# %%
query = RawTwitterComments.select() \
        .where(
            (SQL('length(clean_comment) > 0')) & 
            (RawTwitterComments.candidate == 'Jair Bolsonaro')
        ) \
        .order_by(RawTwitterComments.timestamp)

# %%
dates = comments_by_date(query)
dts = list(dates.keys())
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')
print(f'Data de coleta               : {dts[0]} <=> {dts[-1]}')
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 32712
# Média palavras por Comentário: 6.76
# Qtde de Usuários             : 16334
# Data de coleta               : 12/03/2018 <=> 28/10/2018

# %%
create_wordcloud(query)

# %%
graph_most_words_freq_by_date(RawTwitterComments, query, turno=2, candidato='Jair Bolsonaro', most_common=10)

# %%
graph_comment_by_date(dates)

# %% [markdown]
# ## Fernando Haddad

# %%
query = RawTwitterComments.select() \
        .where(
            (SQL('length(clean_comment) > 0')) & 
            (RawTwitterComments.candidate == 'Fernando Haddad')
        ) \
        .order_by(RawTwitterComments.timestamp)

# %%
dates = comments_by_date(query)
dts = list(dates.keys())
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')
print(f'Data de coleta               : {dts[0]} <=> {dts[-1]}')
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 31760
# Média palavras por Comentário: 6.96
# Qtde de Usuários             : 15388
# Data de coleta               : 21/08/2018 <=> 28/10/2018

# %%
create_wordcloud(query)

# %%
graph_most_words_freq_by_date(RawTwitterComments, query, turno=0, candidato='Fernando Haddad', most_common=10)

# %%
graph_comment_by_date(dates)

# %% [markdown]
# ## Ciro Gomes

# %%
query = RawTwitterComments.select() \
        .where(
            (SQL('length(clean_comment) > 0')) & 
            (RawTwitterComments.candidate == 'Ciro Gomes')
        ) \
        .order_by(RawTwitterComments.timestamp)

# %%
dates = comments_by_date(query)
dts = list(dates.keys())
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')
print(f'Data de coleta               : {dts[0]} <=> {dts[-1]}')
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 17217
# Média palavras por Comentário: 5.8
# Qtde de Usuários             : 8973
# Data de coleta               : 15/08/2018 <=> 28/10/2018

# %%
create_wordcloud(query)

# %%
graph_most_words_freq_by_date(RawTwitterComments, query, turno=0, candidato='Ciro Gomes', most_common=10)

# %%
graph_comment_by_date(dates)

# %% [markdown]
# ## Geraldo Alckmin

# %%
query = RawTwitterComments.select() \
        .where(
            (SQL('length(clean_comment) > 0')) & 
            (RawTwitterComments.candidate == 'Geraldo Alckmin')
        ) \
        .order_by(RawTwitterComments.timestamp)

# %%
dates = comments_by_date(query)
dts = list(dates.keys())
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')
print(f'Data de coleta               : {dts[0]} <=> {dts[-1]}')
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 16324
# Média palavras por Comentário: 7.07
# Qtde de Usuários             : 8047
# Data de coleta               : 04/08/2018 <=> 20/10/2018

# %%
create_wordcloud(query)

# %%
graph_most_words_freq_by_date(RawTwitterComments, query, turno=0, candidato='Geraldo Alckmin', most_common=10)

# %%
graph_comment_by_date(dates)

# %% [markdown]
# ## Marina Silva

# %%
query = RawTwitterComments.select() \
        .where(
            (SQL('length(clean_comment) > 0')) & 
            (RawTwitterComments.candidate == 'Marina Silva')
        ) \
        .order_by(RawTwitterComments.timestamp)

# %%
dates = comments_by_date(query)
dts = list(dates.keys())
words = word_frequency(query)
words_c = word_count(query)

print('Estatísticas')
print('-' * 20)
print(f'Qtde de Comentários          : {len(query)}')
print(f'Média palavras por Comentário: {round(words_c/len(query), 2)}')
print(f'Qtde de Usuários             : {len(unique_users(query))}')
print(f'Data de coleta               : {dts[0]} <=> {dts[-1]}')
# Out:
# Estatísticas
# --------------------
# Qtde de Comentários          : 22069
# Média palavras por Comentário: 7.2
# Qtde de Usuários             : 9401
# Data de coleta               : 06/08/2018 <=> 28/10/2018

# %%
create_wordcloud(query)

# %%
graph_most_words_freq_by_date(RawTwitterComments, query, turno=0, candidato='Marina Silva', most_common=10)

# %%
graph_comment_by_date(dates)
